# %% [markdown]
# <a href="https://colab.research.google.com/github/vaishnavimangore2007-prog/VSM/blob/main/Untitled9.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a=(input("lengh of string:"))
print(a)
# Out:
# lengh of string:20
# 20
