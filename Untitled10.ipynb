# %% [markdown]
# <a href="https://colab.research.google.com/github/vaishnavimangore2007-prog/VSM/blob/main/Untitled10.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a=input("enter first string:")
b=input("enter second string")
c=a+b
print(c)
# Out:
# enter first string:6
# enter second string7
# 67
